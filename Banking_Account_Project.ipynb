# %%
def split_info(info):
    info = info.split()
    all_info = ''
    for item in info:
        all_info += item
    return all_info



def copy_file(path):
    import csv
    copy_file = "copy_" + path
    try:
        with open(path) as file:
            cr = csv.reader(file)
            with open(copy_file, 'w', newline="") as copy_file:
                cw = csv.writer(copy_file)
                for item in cr:
                    cw.writerow(item)
        print("File was coppied successfully")
        return True
    except Exception as e:
        print(e)
        return False



def appending_file(path, lst):
    import csv
    lst = [lst]
    with open(path, 'a', newline='') as file:
        writer = csv.writer(file)
        writer.writerows(lst)



def search_value_managem(path,value,index):
    """
    index:
    number          = 0
    first_name      = 1
    last_name       = 2
    gender          = 3
    city            = 4
    address         = 5
    mobile_number   = 6
    province        = 7
    user_name       = 8
    password        = 9
    management_code = 10
    """
    with open(path) as file:
        import csv
        csv_reader = csv.reader(file, delimiter=',')
        file_contents = []
        for row in csv_reader:
            if value in row[index]:
                return True
        else:
            return False



def save_list(lst_save):
    path = "Managem.csv"
    capacity2 = search_value_managem(path, 'M002', 0)
    capacity3 = search_value_managem(path, 'M003', 0)
    if capacity2 == False:
        lst_save.insert(0,'M002')
        appending_file(path, lst_save)
    elif capacity3 == False:
        lst_save.insert(0,'M003')
        appending_file(path, lst_save)
    else:
        return'Sorry not find capacity!!!'



def search(path,index):
    with open(path) as file:
        import csv
        csv_reader = csv.reader(file, delimiter=',')
        file_contents = []
        lst = []
        for row in csv_reader:
            lst.append(row[index])
        else:
            return lst[-1]
        


def login(type_user):
    type_user = int(type_user)
    n_lst = [chr(x) for x in range(48, 58)]
    l_lst = [chr(x) for x in range(65, 91)]
    s_lst = [chr(x) for x in range(97, 123)]
    c_lst = ['!', '@', '#', '$', '%', '^', '&', '*', '~', '.']
    n, l, s, c = 0, 0, 0, 0
    key, key_user = True, True
    while key == True:
        if key_user == True:
            #User name filtering
            user_name = input("Please enter username:\n")
            if len(user_name) >= type_user:
                for i in user_name:
                    if i in n_lst:
                        n += 1
                    elif i in l_lst:
                        l += 1
                    elif i in s_lst:
                        s += 1
                    elif i in c_lst:
                        c += 1
                    elif i == ' ':
                        pass
                else:
                    if n >= 1 and l >= 1 and s >= 1 and c >= 1:
                        path = "Normal_user"
                        saerch = search_value_managem(path,user_name,11)
                        if saerch == True:
                           key_user = False
        else:
            #If the user name is done, it goes to the password
            #Password filtering
            password  = input("Please enter password:\n")
            if len(password) >= type_user:
                if password != user_name:
                    for i in password:
                        if i in n_lst:
                            n += 1
                        elif i in l_lst:
                            l += 1
                        elif i in s_lst:
                            s += 1
                        elif i in c_lst:
                            c += 1
                        elif i == ' ':
                            pass
                    else:
                        if n >= 1 and l >= 1 and s >= 1 and c >= 1:
                            path = "Normal_user"
                            saerch = search_value_managem(path,password,12)
                            if saerch == True:
                                number = input("Please enter a your number for find")
                                if number.isalnum() == True:
                                    key = False
                                    return True
                                


def loc(path, *number):
    number = int(input()) +1
    saerch = search_value_managem(path,number,0)
    if saerch == True:
        with open(path) as file:
            import pandas as pd
            df = pd.read_csv(file)
            return df.iloc[number]
        


def update_csv(path, new_value, row_num, num):
    with open(path,'r') as file:
        import csv
        reader = csv.reader(file)
        rows = list(reader)
        rows[row_num][num] = new_value
        with open(path,'w', newline='') as file:
            writer = csv.writer(file)
            writer.writerows(rows)



def search_value001(path,value,index):
    with open(path) as file:
        import csv
        csv_reader = csv.reader(file, delimiter=',')
        file_contents = []
        for row in csv_reader:
            if value in row[index]:
                return row
        else:
            return False
        


def time():
    import time
    current_time = time.localtime()
    formatted_time = time.strftime("%Y-%m-%d %H:%M:%S",current_time)
    return formatted_time

# %%
def filters(user_type, first_name, last_name, gender, city, address, mobile_number, *etc):
    #To save the data if everything was entered correctly
    lst_save = []



    #First_name filtering
    first_name = split_info(first_name)
    if first_name.isalpha() == True:
        lst_save = lst_save.append(first_name)
    else:
        first_name = input("Please enter again your first name:\n")
        if first_name.isalpha() == True:
            lst_save = lst_save.append(first_name)
        else:
            return"Sorry, you didn't enter the information correctly!\nPlease try again later"



    #Last_name filtering
    last_name = split_info(last_name)
    if last_name.isalpha() == True:
        lst_save = lst_save.append(last_name)
    else:
        last_name = input("Please enter again your last name:\n")
        if last_name.isalpha() == True:
            lst_save = lst_save.append(last_name)
        else:
            return"Sorry, you didn't enter the information correctly!\nPlease try again later"
    


    #Gender filtering
    gender = split_info(gender)
    if gender.isalpha() == True:
        gender = gender.title()
        if gender == 'Male' or 'Female' or 'Etc':
            lst_save = lst_save.append(gender)
        else:
            print("I don't understand")
            gender = input("Your gender(please enter a number):\n1.Male\n2.Female\n3.Etc\n")
            if gender.isalpha() == True:
                gender = gender.title()
                if gender == 'Male' or 'Female' or 'Etc':
                    lst_save = lst_save.append(gender)
                else:
                    return"Sorry, you didn't enter the information correctly!\nPlease try again later"
            elif gender.isnumeric() == True:
                gender = int(gender)
                if gender == 1 or 2 or 3:
                    if gender == 1:
                        gender = 'Male'
                        lst_save = lst_save.append(gender)
                    elif gender == 2:
                        gender = 'Female'
                        lst_save = lst_save.append(gender)
                    else:
                        gender = 'Etc'
                        lst_save = lst_save.append(gender)
                else:
                    return"Sorry, you didn't enter the information correctly!\nPlease try again later"
            else:
                return"Sorry, you didn't enter the information correctly!\nPlease try again later"
            
    elif gender.isnumeric() == True:
                gender = int(gender)
                if gender == 1 or 2 or 3:
                    if gender == 1:
                        gender = 'Male'
                        lst_save = lst_save.append(gender)
                    elif gender == 2:
                        gender = 'Female'
                        lst_save = lst_save.append(gender)
                    else:
                        gender = 'Etc'
                        lst_save = lst_save.append(gender)
                else:
                    print("I don't understand")
                    gender = input("Your gender(please enter a number):\n1.Male\n2.Female\n3.Etc\n")
                    if gender.isalpha() == True:
                        gender = gender.title()
                        if gender == 'Male' or 'Female' or 'Etc':
                            lst_save = lst_save.append(gender)
                        else:
                            return"Sorry, you didn't enter the information correctly!\nPlease try again later"
                    elif gender.isnumeric() == True:
                        gender = int(gender)
                        if gender == 1 or 2 or 3:
                            if gender == 1:
                                gender = 'Male'
                                lst_save = lst_save.append(gender)
                            elif gender == 2:
                                gender = 'Female'
                                lst_save = lst_save.append(gender)
                            else:
                                gender = 'Etc'
                                lst_save = lst_save.append(gender)
                    else:
                        return"Sorry, you didn't enter the information correctly!\nPlease try again later"
    else:
        print("I don't understand")
        gender = input("Your gender(please enter a number):\n1.Male\n2.Female\n3.Etc\n")
        if gender.isalpha() == True:
            gender = gender.title()
            if gender == 'Male' or 'Female' or 'Etc':
                lst_save = lst_save.append(gender)
            else:
                return"Sorry, you didn't enter the information correctly!\nPlease try again later"
        elif gender.isnumeric() == True:
            gender = int(gender)
            if gender == 1 or 2 or 3:
                if gender == 1:
                    gender = 'Male'
                    lst_save = lst_save.append(gender)
                elif gender == 2:
                    gender = 'Female'
                    lst_save = lst_save.append(gender)
                else:
                    gender = 'Etc'
                    lst_save = lst_save.append(gender)
            else:
                return"Sorry, you didn't enter the information correctly!\nPlease try again later"
        else:
            return"Sorry, you didn't enter the information correctly!\nPlease try again later"
    


    #City filtering
    city = split_info(city)
    if city.isalpha() == True:
        lst_save = lst_save.append(city)
    else:
        city = input("In which city do you live?\n")
        if city.isalpha() == True:
            lst_save = lst_save.append(city)
        else:
            return"Sorry, you didn't enter the information correctly!\nPlease try again later"
    


    #Address filtering
    #The address cannot be filtered because it contains numbers and letters!
    lst_save = lst_save.append(address)


    
    #Mobile_number filtering
    mobile_number = split_info(mobile_number)
    lst_mobile_number = [
        910, 911, 912, 913, 914, 915, 916, 917, 918, 919,
        990, 991, 992, 993, 994, 930, 933, 935, 936, 937,
        938, 939, 901, 902, 903, 904, 905, 941, 920, 921,
    ]
    #First, we check if the number uses letters
    if mobile_number.isnumeric() == True:
        #If it had 0
        if mobile_number[0] == '0':
            mobile_number = mobile_number[1::]
            if mobile_number[:3:] in lst_mobile_number:
                lst_save = lst_save.append(mobile_number)
            else:
                mobile_number = input("and mobile number:\n")
                if mobile_number.isnumeric() == True:
                    if mobile_number[0] == '0':
                        mobile_number = mobile_number[1::]
                        if mobile_number[:3:] in lst_mobile_number:
                            lst_save = lst_save.append(mobile_number)
                        else:
                            return"Sorry, you didn't enter the information correctly!\nPlease try again later"
                    else:
                        return"Sorry, you didn't enter the information correctly!\nPlease try again later"
                else:
                    return"Sorry, you didn't enter the information correctly!\nPlease try again later"
        #If it didn't have 0
        else:
            if mobile_number[:3:] in lst_mobile_number:
                lst_save = lst_save.append(mobile_number)
            else:
                mobile_number = input("and mobile number:\n")
                if mobile_number.isnumeric() == True:
                    if mobile_number[0] == '0':
                        mobile_number = mobile_number[1::]
                        if mobile_number[:3:] in lst_mobile_number:
                            lst_save = lst_save.append(mobile_number)
                        else:
                            return"Sorry, you didn't enter the information correctly!\nPlease try again later"
                    else:
                        return"Sorry, you didn't enter the information correctly!\nPlease try again later"
                else:
                    return"Sorry, you didn't enter the information correctly!\nPlease try again later"
    else:
        mobile_number = input("and mobile number:\n")
        if mobile_number.isnumeric() == True:
            #If it had 0
            if mobile_number[0] == '0':
                mobile_number = mobile_number[1::]
                if mobile_number[:3:] in lst_mobile_number:
                    lst_save = lst_save.append(mobile_number)
                else:
                    return"Sorry, you didn't enter the information correctly!\nPlease try again later"
            #If it didn't have 0
            else:
                if mobile_number[:3:] in lst_mobile_number:
                    lst_save = lst_save.append(mobile_number)
        else:
            return"Sorry, you didn't enter the information correctly!\nPlease try again later"
    


    #Ext filtering
    if user_type == 'Management':
        province =  etc[0]
        province = split_info(province)
        #If the province is saved
        if province.isalpha() == True:
            lst_save = lst_save.append(province)
            n_lst = [chr(x) for x in range(48, 58)]
            l_lst = [chr(x) for x in range(65, 91)]
            s_lst = [chr(x) for x in range(97, 123)]
            c_lst = ['!', '@', '#', '$', '%', '^', '&', '*', '~', '.']
            n, l, s, c = 0, 0, 0, 0
            key, key_user = True, True
            while key == True:
                if key_user == True:
                    #User name filtering
                    user_name = input("Please enter username:\n")
                    if len(user_name) >= 10:
                        for i in user_name:
                            if i in n_lst:
                                n += 1
                            elif i in l_lst:
                                l += 1
                            elif i in s_lst:
                                s += 1
                            elif i in c_lst:
                                c += 1
                            elif i == ' ':
                                pass
                        else:
                            if n >= 1 and l >= 1 and s >= 1 and c >= 1:
                                lst_save.append(user_name)
                                key_user = False
                else:
                    #If the user name is done, it goes to the password
                    #Password filtering
                    password  = input("Please enter password:\n")
                    if len(password) >= 10:
                        if password != user_name:
                            for i in password:
                                if i in n_lst:
                                    n += 1
                                elif i in l_lst:
                                    l += 1
                                elif i in s_lst:
                                    s += 1
                                elif i in c_lst:
                                    c += 1
                                elif i == ' ':
                                    pass
                            else:
                                if n >= 1 and l >= 1 and s >= 1 and c >= 1:
                                    path = "Managem.csv"
                                    saerch = search_value_managem(path,password,9)
                                    if saerch == False:
                                        lst_save.append(password)
                                        key = False
        else:
            province = input("Which province are you in?\n")
            if province.isalpha() == True:
                lst_save = lst_save.append(province)
                #If the province is saved
                while key == True:
                    if key_user == True:
                        #User name filtering
                        user_name = input("Please enter username:\n")
                        if len(user_name) >= 10:
                            for i in user_name:
                                if i in n_lst:
                                    n += 1
                                elif i in l_lst:
                                    l += 1
                                elif i in s_lst:
                                    s += 1
                                elif i in c_lst:
                                    c += 1
                                elif i == ' ':
                                    pass
                            else:
                                if n >= 1 and l >= 1 and s >= 1 and c >= 1:
                                    lst_save.append(user_name)
                                    key_user = False
                    else:
                        #If the user name is done, it goes to the password
                        #Password filtering
                        password  = input("Please enter password:\n")
                        if len(password) >= 10:
                            if password != user_name:
                                for i in password:
                                    if i in n_lst:
                                        n += 1
                                    elif i in l_lst:
                                        l += 1
                                    elif i in s_lst:
                                        s += 1
                                    elif i in c_lst:
                                        c += 1
                                    elif i == ' ':
                                        pass
                                else:
                                    if n >= 1 and l >= 1 and s >= 1 and c >= 1:
                                        path = "Managem.csv"
                                        saerch = search_value_managem(path,password,9)
                                        if saerch == False:
                                            lst_save.append(password)
                                            key = False
            else:
                return"Sorry, you didn't enter the information correctly!\nPlease try again later"
    else:
        if user_type == 'Normal_user':
            country         = etc[0]
            age             = etc[1]
            landline_number = etc[2]
            gmail           = etc[3]
            initial_amount  = etc[4]
            country         = split_info(country)
            age             = split_info(age)
            landline_number = split_info(landline_number)
            gmail           = split_info(gmail)
            initial_amount  = split_info(initial_amount)
            #Country filtering
            if country.isalpha() == True:
                lst_save = lst_save.append(country)
            else:
                country = input("Country:\n")
                if country.isalpha() == True:
                    lst_save = lst_save.append(country)
                else:
                    return"Sorry, you didn't enter the information correctly!\nPlease try again later"
                
            
            #Age filtering
            if age.isalnum() == True:
                if int(age) >= 18:
                    lst_save = lst_save.append(age)
                else:
                    return"sorry, you aren't of legal age"
            else:
                age = input("How old are you?")
                if age.isalnum() == True:
                    if int(age) >= 18:
                        lst_save = lst_save.append(age)
                    else:
                        return"sorry, you aren't of legal age"
                else:
                    return"Sorry, you didn't enter the information correctly!\nPlease try again later"
                
            
            #Landline_number filtering
            if landline_number.isalnum() == True:
                if len(landline_number) == 11:
                    lst_save = lst_save.append(landline_number)
                else:
                    landline_number = input("Landline number:\n")
                    if landline_number.isalnum() == True:
                        if len(landline_number) == 11:
                            lst_save = lst_save.append(landline_number)
                        else:
                            return"Sorry, you didn't enter the information correctly!\nPlease try again later"
                    else:
                        return"Sorry, you didn't enter the information correctly!\nPlease try again later"
            else:
                landline_number = input("Landline number:\n")
                if landline_number.isalnum() == True:
                    if len(landline_number) == 11:
                        lst_save = lst_save.append(landline_number)
                    else:
                        return"Sorry, you didn't enter the information correctly!\nPlease try again later"
                else:
                    return"Sorry, you didn't enter the information correctly!\nPlease try again later"
            #Gmail filtering
            if len(gmail) >= 17:
                if '@gmail.com' in gmail:
                    lst_save = lst_save.append(gmail)
                else:
                    gmail = input("Please enter your gmail:\n")
                    if len(gmail) >= 17:
                        if '@gmail.com' in gmail:
                            lst_save = lst_save.append(gmail)
                        else:
                            return"Sorry, you didn't enter the information correctly!\nPlease try again later"
                    else:
                        return"Sorry, you didn't enter the information correctly!\nPlease try again later"
            else:
                gmail = input("Please enter your gmail:\n")
                if len(gmail) >= 17:
                    if '@gmail.com' in gmail:
                        lst_save = lst_save.append(gmail)
                    else:
                        return"Sorry, you didn't enter the information correctly!\nPlease try again later"
                else:
                    return"Sorry, you didn't enter the information correctly!\nPlease try again later"
            #Initial_amount filtering
            if initial_amount.isalnum() == True:
                if int(initial_amount) >= 200:
                    lst_save = lst_save.append(initial_amount)
                    lst_save = lst_save.append(initial_amount)
                    #If the province is saved
                    if province.isalpha() == True:
                        lst_save = lst_save.append(province)
                        n_lst = [chr(x) for x in range(48, 58)]
                        l_lst = [chr(x) for x in range(65, 91)]
                        s_lst = [chr(x) for x in range(97, 123)]
                        c_lst = ['!', '@', '#', '$', '%', '^', '&', '*', '~', '.']
                        n, l, s, c = 0, 0, 0, 0
                        key, key_user = True, True
                        while key == True:
                            if key_user == True:
                                #User name filtering
                                user_name = input("Please enter username:\n")
                                if len(user_name) >= 8:
                                    for i in user_name:
                                        if i in n_lst:
                                            n += 1
                                        elif i in l_lst:
                                            l += 1
                                        elif i in s_lst:
                                            s += 1
                                        elif i in c_lst:
                                            c += 1
                                        elif i == ' ':
                                            pass
                                    else:
                                        if n >= 1 and l >= 1 and s >= 1 and c >= 1:
                                            lst_save.append(user_name)
                                            key_user = False
                            else:
                                #If the user name is done, it goes to the password
                                #Password filtering
                                password  = input("Please enter password:\n")
                                if len(password) >= 8:
                                    if password != user_name:
                                        for i in password:
                                            if i in n_lst:
                                                n += 1
                                            elif i in l_lst:
                                                l += 1
                                            elif i in s_lst:
                                                s += 1
                                            elif i in c_lst:
                                                c += 1
                                            elif i == ' ':
                                                pass
                                        else:
                                            if n >= 1 and l >= 1 and s >= 1 and c >= 1:
                                                path = "Normal_user"
                                                saerch = search_value_managem(path,password,9)
                                                if saerch == False:
                                                    lst_save.append(password)
                                                    key = False 
                else:
                    return"This amount is too small to open an account"
            else:
                if initial_amount.isalnum() == True:
                    if int(initial_amount) >= 200:
                        lst_save = lst_save.append(initial_amount)
                        lst_save = lst_save.append(initial_amount)
                        #If the province is saved
                        if province.isalpha() == True:
                            lst_save = lst_save.append(province)
                            n_lst = [chr(x) for x in range(48, 58)]
                            l_lst = [chr(x) for x in range(65, 91)]
                            s_lst = [chr(x) for x in range(97, 123)]
                            c_lst = ['!', '@', '#', '$', '%', '^', '&', '*', '~', '.']
                            n, l, s, c = 0, 0, 0, 0
                            key, key_user = True, True
                            while key == True:
                                if key_user == True:
                                    #User name filtering
                                    user_name = input("Please enter username:\n")
                                    if len(user_name) >= 8:
                                        for i in user_name:
                                            if i in n_lst:
                                                n += 1
                                            elif i in l_lst:
                                                l += 1
                                            elif i in s_lst:
                                                s += 1
                                            elif i in c_lst:
                                                c += 1
                                            elif i == ' ':
                                                pass
                                        else:
                                            if n >= 1 and l >= 1 and s >= 1 and c >= 1:
                                                lst_save.append(user_name)
                                                key_user = False
                                else:
                                    #If the user name is done, it goes to the password
                                    #Password filtering
                                    password  = input("Please enter password:\n")
                                    if len(password) >= 8:
                                        if password != user_name:
                                            for i in password:
                                                if i in n_lst:
                                                    n += 1
                                                elif i in l_lst:
                                                    l += 1
                                                elif i in s_lst:
                                                    s += 1
                                                elif i in c_lst:
                                                    c += 1
                                                elif i == ' ':
                                                    pass
                                            else:
                                                if n >= 1 and l >= 1 and s >= 1 and c >= 1:
                                                    path = "Normal_user"
                                                    saerch = search_value_managem(path,password,9)
                                                    if saerch == False:
                                                        lst_save.append(password)
                                                        key = False 
                    else:
                        return"This amount is too small to open an account"
                else:
                    return"Sorry, you didn't enter the information correctly!\nPlease try again later"
    #Data saving
    if user_type == 'Management':
        path = "Managem.csv"
        save_list(lst_save)
    else:
        path = "Normal_user"
        capacity = int(search(path, 0))
        capacity += 1
        lst_save.insert(0,capacity)
        appending_file(path, lst_save)

# %%
def update_fname(first_name):
    #First_name filtering
    first_name = split_info(first_name)
    if first_name.isalpha() == True:
        return first_name
    else:
        first_name = input("Please enter again your first name:\n")
        if first_name.isalpha() == True:
            return first_name
        else:
            return False


def update_lname(last_name):
    #Last_name filtering
    last_name = split_info(last_name)
    if last_name.isalpha() == True:
        return last_name
    else:
        last_name = input("Please enter again your last name:\n")
        if last_name.isalpha() == True:
            return last_name
        else:
            return False
    

def update_gender(gender):
    #Gender filtering
    gender = split_info(gender)
    if gender.isalpha() == True:
        gender = gender.title()
        if gender == 'Male' or 'Female' or 'Etc':
            return gender
        else:
            print("I don't understand")
            gender = input("Your gender(please enter a number):\n1.Male\n2.Female\n3.Etc\n")
            if gender.isalpha() == True:
                gender = gender.title()
                if gender == 'Male' or 'Female' or 'Etc':
                    return gender
                else:
                    return False
            elif gender.isnumeric() == True:
                gender = int(gender)
                if gender == 1 or 2 or 3:
                    if gender == 1:
                        gender = 'Male'
                        return gender
                    elif gender == 2:
                        gender = 'Female'
                        return gender
                    else:
                        gender = 'Etc'
                        return gender
                else:
                    return False
            else:
                return False
            
    elif gender.isnumeric() == True:
                gender = int(gender)
                if gender == 1 or 2 or 3:
                    if gender == 1:
                        gender = 'Male'
                        return gender
                    elif gender == 2:
                        gender = 'Female'
                        return gender
                    else:
                        gender = 'Etc'
                        return gender
                else:
                    print("I don't understand")
                    gender = input("Your gender(please enter a number):\n1.Male\n2.Female\n3.Etc\n")
                    if gender.isalpha() == True:
                        gender = gender.title()
                        if gender == 'Male' or 'Female' or 'Etc':
                            return gender
                        else:
                            return False
                    elif gender.isnumeric() == True:
                        gender = int(gender)
                        if gender == 1 or 2 or 3:
                            if gender == 1:
                                gender = 'Male'
                                return gender
                            elif gender == 2:
                                gender = 'Female'
                                return gender
                            else:
                                gender = 'Etc'
                                return gender
                    else:
                        return False
    else:
        print("I don't understand")
        gender = input("Your gender(please enter a number):\n1.Male\n2.Female\n3.Etc\n")
        if gender.isalpha() == True:
            gender = gender.title()
            if gender == 'Male' or 'Female' or 'Etc':
                return gender
            else:
                return False
        elif gender.isnumeric() == True:
            gender = int(gender)
            if gender == 1 or 2 or 3:
                if gender == 1:
                    gender = 'Male'
                    return gender
                elif gender == 2:
                    gender = 'Female'
                    return gender
                else:
                    gender = 'Etc'
                    return gender
            else:
                return False
        else:
            return False
    

def update_city(city):
    #City filtering
    city = split_info(city)
    if city.isalpha() == True:
        return city
    else:
        city = input("In which city do you live?\n")
        if city.isalpha() == True:
            return city
        else:
            return False
    

def update_address(address):
    #Address filtering
    #The address cannot be filtered because it contains numbers and letters!
    return address


def update_mobile_number(mobile_number):
    #Mobile_number filtering
    mobile_number = split_info(mobile_number)
    lst_mobile_number = [
        910, 911, 912, 913, 914, 915, 916, 917, 918, 919,
        990, 991, 992, 993, 994, 930, 933, 935, 936, 937,
        938, 939, 901, 902, 903, 904, 905, 941, 920, 921,
    ]
    #First, we check if the number uses letters
    if mobile_number.isnumeric() == True:
        #If it had 0
        if mobile_number[0] == '0':
            mobile_number = mobile_number[1::]
            if mobile_number[:3:] in lst_mobile_number:
                return mobile_number
            else:
                mobile_number = input("and mobile number:\n")
                if mobile_number.isnumeric() == True:
                    if mobile_number[0] == '0':
                        mobile_number = mobile_number[1::]
                        if mobile_number[:3:] in lst_mobile_number:
                            return mobile_number
                        else:
                            return False
                    else:
                        return False
                else:
                    return False
        #If it didn't have 0
        else:
            if mobile_number[:3:] in lst_mobile_number:
                return mobile_number
            else:
                mobile_number = input("and mobile number:\n")
                if mobile_number.isnumeric() == True:
                    if mobile_number[0] == '0':
                        mobile_number = mobile_number[1::]
                        if mobile_number[:3:] in lst_mobile_number:
                            return mobile_number
                        else:
                            return False
                    else:
                        return False
                else:
                    return False
    else:
        mobile_number = input("and mobile number:\n")
        if mobile_number.isnumeric() == True:
            #If it had 0
            if mobile_number[0] == '0':
                mobile_number = mobile_number[1::]
                if mobile_number[:3:] in lst_mobile_number:
                    return mobile_number
                else:
                    return False
            #If it didn't have 0
            else:
                if mobile_number[:3:] in lst_mobile_number:
                    return mobile_number
        else:
            return False
    

def update_province(province):
    province = split_info(province)
    #If the province is saved
    if province.isalpha() == True:
        return province
    else:
        province = input("Which province are you in?\n")
        if province.isalpha() == True:
            return province
        else:
            return False
        
        
        
        
def update_username(number):
    number         = int(number)
    n_lst = [chr(x) for x in range(48, 58)]
    l_lst = [chr(x) for x in range(65, 91)]
    s_lst = [chr(x) for x in range(97, 123)]
    c_lst = ['!', '@', '#', '$', '%', '^', '&', '*', '~', '.']
    n, l, s, c = 0, 0, 0, 0
    key = True
    while key == True:
        #User name filtering
        user_name = input("Please enter username:\n")
        if len(user_name) >= number:
            for i in user_name:
                if i in n_lst:
                    n += 1
                elif i in l_lst:
                    l += 1
                elif i in s_lst:
                    s += 1
                elif i in c_lst:
                    c += 1
                elif i == ' ':
                    pass
            else:
                if n >= 1 and l >= 1 and s >= 1 and c >= 1:
                    key = False
                    return user_name
                    
                    
                    
def update_password(number):
    number         = int(number)
    n_lst = [chr(x) for x in range(48, 58)]
    l_lst = [chr(x) for x in range(65, 91)]
    s_lst = [chr(x) for x in range(97, 123)]
    c_lst = ['!', '@', '#', '$', '%', '^', '&', '*', '~', '.']
    n, l, s, c = 0, 0, 0, 0
    key = True
    while key == True:
        #If the user name is done, it goes to the password
        #Password filtering
        password  = input("Please enter password:\n")
        if len(password) >= number:
            if password != password:
                for i in password:
                    if i in n_lst:
                        n += 1
                    elif i in l_lst:
                        l += 1
                    elif i in s_lst:
                        s += 1
                    elif i in c_lst:
                        c += 1
                    elif i == ' ':
                        pass
                else:
                    if n >= 1 and l >= 1 and s >= 1 and c >= 1:
                        if number == 8:
                            path = 'Normal_user'
                            saerch = search_value_managem(path,password,14)
                            if saerch == False:
                                key = False
                                return password
                        else:    
                            path = "Managem.csv"
                            saerch = search_value_managem(path,password,14)
                            if saerch == False:
                                key = False
                                return password
                                
                                
                                
def update_contry(contry):
    country     = split_info(country)
    #Country filtering
    if country.isalpha() == True:
        return contry
    else:
        country = input("Country:\n")
        if country.isalpha() == True:
            return contry
        else:
            return False
            
            
            
def update_age(age):
    age      = split_info(age)
    #Age filtering
    if age.isalnum() == True:
        if int(age) >= 18:
            return age
        else:
            return False
    else:
        age = input("How old are you?")
        if age.isalnum() == True:
            if int(age) >= 18:
                return age
            else:
                return False
        else:
            return False
            
            
            
def update_landline_number(landline_number):
    landline_number      = split_info(landline_number)
    #Landline_number filtering
    if landline_number.isalnum() == True:
        if len(landline_number) == 11:
            return landline_number
        else:
            landline_number = input("Landline number:\n")
            if landline_number.isalnum() == True:
                if len(landline_number) == 11:
                    return landline_number
                else:
                    return False
            else:
                return False
    else:
        landline_number = input("Landline number:\n")
        if landline_number.isalnum() == True:
            if len(landline_number) == 11:
                return landline_number
            else:
                return False
        else:
            return False
            
            
            
def update_gmail(gmail):
    gmail      = split_info(gmail)
    #Gmail filtering
    if len(gmail) >= 17:
        if '@gmail.com' in gmail:
            return gmail
        else:
            gmail = input("Please enter your gmail:\n")
            if len(gmail) >= 17:
                if '@gmail.com' in gmail:
                    return gmail
                else:
                    return False
            else:
                return False
    else:
        gmail = input("Please enter your gmail:\n")
        if len(gmail) >= 17:
            if '@gmail.com' in gmail:
                return gmail
            else:
                return False
        else:
            return False

# %%
def new_user():
    #Key to the correctness of user information
    key = False

    """To register the new manager:
        1.The first step is to get information from the user
        The first strage has two modes:1.question and answer 2.linear"""
            
    #Giving the user the right to choose
    item = input("How do you enter information?\n1.Question and answer\n2.Linear\n(please use 1 and 2):\n")
    if item.isalpha() == False:
        item = input("How do you enter information?\n1.Question and answer\n2.Linear\n(please use 1 and 2):\n")

        """If the user enters the number 1, he must enter the information linearly"""
    if item == '1':
        lst_new_normal_user = input("The information consists of:\n1.first name\n2.last name\n3.gender\n4.country\n5.city\n6.address\n7.age\n8.landline numbe\n9.mobile number\n10.gmail\n11.initial amount\nNOT:PLEASE WRITE IN ORDER\n")
        lnm = lst_new_normal_user.split()
        #If the number is correct, the information is saved and enters step 2(that is, check the information)
        if len(lnm) == 7:
            first_name      = lnm[0]
            last_name       = lnm[1]
            gender          = lnm[2]
            country         = lnm[3]
            city            = lnm[4]
            address         = lnm[5]
            age             = lnm[6]
            landline_number = lnm[7]
            mobile_number   = lnm[8]
            gmail           = lnm[9]
            initial_amount  = lnm[10]
            key             = True
        #If it was wrong, we will give the user a chance
        else:
                print("Try again later")

        """If the user enters the number 2, he must enter the information in the form of a question"""
    elif item == '2':
        first_name      = input("What is your name?\n")
        last_name       = input("And your last name?\n")
        gender          = input("Your gender(please enter a number):\n1.Male\n2.Female\n3.Etc\n")
        country         = input("Country:\n")
        city            = input("In which city do you live?\n")
        address         = input("please enter your address:\n")
        age             = input("How old are you?\n")
        landline_number = input("Landline number:\n")
        mobile_number   = input("And mobile number:\n")
        gmail           = input("Please enter your gmail:\n")
        initial_amount  = input("The minimum amount to open an account is 200!, initial amount?\n")
        key             = True
    else:
        print("Please try again...")
            
    #If it was a key(key == True), filters information
    if key == True:
        #Data filtering
        user_type = 'Normal_user'
        filters(user_type, first_name, last_name, gender, city, address, mobile_number, country, age, landline_number, gmail, initial_amount)
    else:
        print("Please try again later")



def delfile(path, number):
    import csv 
    with open(path) as file:
        reader = csv.reader(file)
        rows = list(reader)
        del rows[int(number)]
        with open(path,'w', newline='') as file:
            writer = csv.writer(file)
            writer.writerows(rows)



def update_rows(path, index):
    # index == 0
    lst = int(search(path, index))
    for value in range(lst+1):
        index_value = str(int(value) + 1)
        value = str(value)
        if search_value001(path, value, index) != index_value:
            index = int(index)
            index_value = int(index_value)
            update_csv(path, value, index_value, index)



def show(path, value):
    import pandas as pd 
    df = pd.read_csv(path)
    return df[value]
    


def transfer_file_in_file(path, new_path):
    import csv
    try:
        with open(new_path) as new_file:
            cr = csv.reader(new_file)
            with open(path, 'a', newline="") as file:
                cw = csv.writer(file)
                for item in cr:
                    cw.writerow(item)
        print("File was coppied successfully")
        return True
    except Exception as e:
        print(e)
        return False

# %%
class user:

    class Management:

        def __init__(self):
            login(10)




        def new_manager(self):
            #Key to the correctness of user information
            key = False

            """To register the new manager:
                1.The first step is to get information from the user
                The first strage has two modes:1.question and answer 2.linear"""
            
            #Giving the user the right to choose
            item = input("How do you enter information?\n1.Question and answer\n2.Linear\n(please use 1 and 2):\n")
            if item.isalpha() == False:
                item = input("How do you enter information?\n1.Question and answer\n2.Linear\n(please use 1 and 2):\n")

                """If the user enters the number 1, he must enter the information linearly"""

            if item == '1':
                lst_new_manager = input("The information consists of:\n1.first name\n2.last name\n3.gender\n4.province\n5.city\n6.address\n7.mobile number\nNOT:PLEASE WRITE IN ORDER\n")
                lnm = lst_new_manager.split()
                #If the number is correct, the information is saved and enters step 2(that is, check the information)
                if len(lnm) == 7:
                    first_name    = lnm[0]
                    last_name     = lnm[1]
                    gender        = lnm[2]
                    province      = lnm[3]
                    city          = lnm[4]
                    address       = lnm[5]
                    mobile_number = lnm[6]
                    key           = True
                #If it was wrong, we will give the user a chance
                else:
                    print("Please try again...")
                    lst_new_manager = input("The information consists of:\n1.first name\n2.last name\n3.gender\n4.province\n5.city\n6.address\n7.mobile number\nNOT:PLEASE WRITE IN ORDER\n")
                    lnm = lst_new_manager.split()
                    if len(lnm) == 7:
                        first_name    = lnm[0]
                        last_name     = lnm[1]
                        gender        = lnm[2]
                        province      = lnm[3]
                        city          = lnm[4]
                        address       = lnm[5]
                        mobile_number = lnm[6]
                        key           = True
                    #If it was wrong again, this text will be print
                    else:
                        print("Try again later")

                """If the user enters the number 2, he must enter the information in the form of a question"""

            elif item == '2':
                first_name    = input("What is your name?\n")
                last_name     = input("And your last name?\n")
                gender        = input("Your gender(please enter a number):\n1.Male\n2.Female\n3.Etc\n")
                province      = input("Which province are you in?\n")
                city          = input("In which city do you live?\n")
                address       = input("Please enter your address:\n")
                mobile_number = input("And mobile number:\n")
                key           = True
            else:
                print("Please try again...")
            
            #If it was a key(key == True), filters information
            if key == True:
                #Data filtering
                user_type = 'Management'
                filters(user_type, first_name, last_name, gender, city, address, mobile_number, province)
            else:
                print("Please try again later")



        def del_manager(self):
            path = "Managem.csv"
            rows = input("Who will be cleared? ")
            row = search_value001(path, rows, 0)
            delfile(path,row)
            if search_value_managem(path, 'M001', 0) == False:
                update_csv(path, 'M001', 2, 0)
            elif search_value_managem(path, 'M002', 0) == False:
                update_csv(path, 'M002', 3, 0)
            elif search_value_managem(path, 'M003', 0) == False:
                    update_csv(path, 'M003', 4, 0)
            


        def new_user_by_manager(self):
            new_user()



        def del_user(self):
            path = "Normal_user"
            rows = input("Who will be cleared? ")
            row = search_value001(path, rows, 0)
            delfile(path,row)
            update_rows(path, 0)
        



        def update_info(self):
            num = input("Update 1.managers or 2.users:")
            if num.isalnum() == True:
                if int(num) == 1:
                    num = input("Which one should be updated?\n1.First name\n2.Last name\n3.Gender\n4.City\n5.Address\n6.Mobile number\n7.Province\n8.User name\n9.Password\nWhich: ")
                    if num.isalnum() == True:
                        num = int(num)
                        if   num == 1:
                            up = update_fname(first_name=input("What is your name?\n"))
                            if up != False:
                                path = "Managem.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 1) == True:
                                    a = search_value001(path, value, 1)
                                    a = a[0]
                                    update_csv(path, up, a, 1)

                        elif num == 2:
                            up = update_lname(last_name=input("And your last name?\n"))
                            if up != False:
                                path = "Managem.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 2) == True:
                                    a = search_value001(path, value, 2)
                                    a = a[0]
                                    update_csv(path, up, a, 2)

                        elif num == 3:
                            up = update_gender(gender=input("Your gender(please enter a number):\n1.Male\n2.Female\n3.Etc\n"))
                            if up != False:
                                path = "Managem.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 3) == True:
                                    a = search_value001(path, value, 3)
                                    a = a[0]
                                    update_csv(path, up, a, 3)

                        elif num == 4:
                            up = update_city(city=input("In which city do you live?\n"))
                            if up != False:
                                path = "Managem.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 4) == True:
                                    a = search_value001(path, value, 4)
                                    a = a[0]
                                    update_csv(path, up, a, 4)

                        elif num == 5:
                            up = update_address(address=input("Please enter your address:\n"))
                            if up != False:
                                path = "Managem.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 5) == True:
                                    a = search_value001(path, value, 5)
                                    a = a[0]
                                    update_csv(path, up, a, 5)

                        elif num == 6:
                            up = update_mobile_number(mobile_number=input("And mobile number:\n"))
                            if up != False:
                                path = "Managem.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 6) == True:
                                    a = search_value001(path, value, 6)
                                    a = a[0]
                                    update_csv(path, up, a, 6)

                        elif num == 7:
                            up = update_province(province=input("Which province are you in?\n"))
                            if up != False:
                                path = "Managem.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 7) == True:
                                    a = search_value001(path, value, 7)
                                    a = a[0]
                                    update_csv(path, up, a, 7)

                        elif num == 8:
                            up = update_username(10)
                            if up != False:
                                path = "Managem.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 8) == True:
                                    a = search_value001(path, value, 8)
                                    a = a[0]
                                    update_csv(path, up, a, 8)

                        elif num == 9:
                            up = update_password(10)
                            if up != False:
                                path = "Managem.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 9) == True:
                                    a = search_value001(path, value, 9)
                                    a = a[0]
                                    update_csv(path, up, a, 9)
                            
                        else:
                            return"Sorry, you didn't enter the information correctly!\nPlease try again later"

                    else:
                        return"Sorry, you didn't enter the information correctly!\nPlease try again later"
                    
                elif int(num) == 2:
                    num = input("Which one should be updated?\n1.First name\n2.Last name\n3.Gender\n4.Country\n5.City\n6.Address\n7.Age\n8.Landline numbe\n9.Mobile number\n10.Gmail\n11.User name\n12.Password\nWhich: ")
                    if num.isalnum() == True:
                        num = int(num)
                        if   num ==  1:
                            up = update_fname(first_name=input("What is your name?\n"))
                            if up != False:
                                path = "Normal_user.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 2) == True:
                                    a = search_value001(path, value, 2)
                                    a = a[0]
                                    update_csv(path, up, a, 2)

                        elif num ==  2:
                            up = update_lname(last_name=input("And your last name?\n"))
                            if up != False:
                                path = "Normal_user.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 3) == True:
                                    a = search_value001(path, value, 3)
                                    a = a[0]
                                    update_csv(path, up, a, 3)

                        elif num ==  3:
                            up = update_gender(gender=input("Your gender(please enter a number):\n1.Male\n2.Female\n3.Etc\n"))
                            if up != False:
                                path = "Normal_user.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 4) == True:
                                    a = search_value001(path, value, 4)
                                    a = a[0]
                                    update_csv(path, up, a, 4)

                        elif num ==  4:
                            up = update_contry(country=input("Country:\n"))
                            if up != False:
                                path = "Normal_user.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 5) == True:
                                    a = search_value001(path, value, 5)
                                    a = a[0]
                                    update_csv(path, up, a, 5)

                        elif num ==  5:
                            up = update_city(city=input("In which city do you live?\n"))
                            if up != False:
                                path = "Normal_user.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 6) == True:
                                    a = search_value001(path, value, 6)
                                    a = a[0]
                                    update_csv(path, up, a, 6)

                        elif num ==  6:
                            up = update_address(address=input("Please enter your address:\n"))
                            if up != False:
                                path = "Normal_user.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 7) == True:
                                    a = search_value001(path, value, 7)
                                    a = a[0]
                                    update_csv(path, up, a, 7)

                        elif num ==  7:
                            up = update_age(age=input("How old are you?\n"))
                            if up != False:
                                path = "Normal_user.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 8) == True:
                                    a = search_value001(path, value, 8)
                                    a = a[0]
                                    update_csv(path, up, a, 8)

                        elif num ==  8:
                            up = update_landline_number(landline_number=input("Landline number:\n"))
                            if up != False:
                                path = "Normal_user.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 9) == True:
                                    a = search_value001(path, value, 9)
                                    a = a[0]
                                    update_csv(path, up, a, 9)

                        elif num ==  9:
                            up = update_mobile_number(mobile_number=input("And mobile number:\n"))
                            if up != False:
                                path = "Normal_user.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 10) == True:
                                    a = search_value001(path, value, 10)
                                    a = a[0]
                                    update_csv(path, up, a, 10)

                        elif num == 10:
                            up = update_gmail(gmail=input("Please enter your gmail:\n"))
                            if up != False:
                                path = "Normal_user.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 11) == True:
                                    a = search_value001(path, value, 11)
                                    a = a[0]
                                    update_csv(path, up, a, 11)

                        elif num == 11:
                            up = update_username(8)
                            if up != False:
                                path = "Normal_user.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 14) == True:
                                    a = search_value001(path, value, 14)
                                    a = a[0]
                                    update_csv(path, up, a, 14)

                        elif num == 12:
                            up = update_password(8)
                            if up != False:
                                path = "Normal_user.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 15) == True:
                                    a = search_value001(path, value, 15)
                                    a = a[0]
                                    update_csv(path, up, a, 15)

                        else:
                            return"Sorry, you didn't enter the information correctly!\nPlease try again later"

                    else:
                        return"Sorry, you didn't enter the information correctly!\nPlease try again later"


                else:
                    return"Sorry, you didn't enter the information correctly!\nPlease try again later"
                

            elif num.isalpha() == True:
                num = num.capitalize()
                if num == 'Managers':
                    num = input("Which one should be updated?\n1.First name\n2.Last name\n3.Gender\n4.City\n5.Address\n6.Mobile number\n7.Province\n8.User name\n9.Password\nWhich: ")
                    if num.isalnum() == True:
                        num = int(num)
                        if   num == 1:
                            up = update_fname(first_name=input("What is your name?\n"))
                            if up != False:
                                path = "Managem.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 1) == True:
                                    a = search_value001(path, value, 1)
                                    a = a[0]
                                    update_csv(path, up, a, 1)

                        elif num == 2:
                            up = update_lname(last_name=input("And your last name?\n"))
                            if up != False:
                                path = "Managem.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 2) == True:
                                    a = search_value001(path, value, 2)
                                    a = a[0]
                                    update_csv(path, up, a, 2)

                        elif num == 3:
                            up = update_gender(gender=input("Your gender(please enter a number):\n1.Male\n2.Female\n3.Etc\n"))
                            if up != False:
                                path = "Managem.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 3) == True:
                                    a = search_value001(path, value, 3)
                                    a = a[0]
                                    update_csv(path, up, a, 3)

                        elif num == 4:
                            up = update_city(city=input("In which city do you live?\n"))
                            if up != False:
                                path = "Managem.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 4) == True:
                                    a = search_value001(path, value, 4)
                                    a = a[0]
                                    update_csv(path, up, a, 4)

                        elif num == 5:
                            up = update_address(address=input("Please enter your address:\n"))
                            if up != False:
                                path = "Managem.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 5) == True:
                                    a = search_value001(path, value, 5)
                                    a = a[0]
                                    update_csv(path, up, a, 5)

                        elif num == 6:
                            up = update_mobile_number(mobile_number=input("And mobile number:\n"))
                            if up != False:
                                path = "Managem.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 6) == True:
                                    a = search_value001(path, value, 6)
                                    a = a[0]
                                    update_csv(path, up, a, 6)

                        elif num == 7:
                            up = update_province(province=input("Which province are you in?\n"))
                            if up != False:
                                path = "Managem.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 7) == True:
                                    a = search_value001(path, value, 7)
                                    a = a[0]
                                    update_csv(path, up, a, 7)

                        elif num == 8:
                            up = update_username(10)
                            if up != False:
                                path = "Managem.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 8) == True:
                                    a = search_value001(path, value, 8)
                                    a = a[0]
                                    update_csv(path, up, a, 8)

                        elif num == 9:
                            up = update_password(10)
                            if up != False:
                                path = "Managem.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 9) == True:
                                    a = search_value001(path, value, 9)
                                    a = a[0]
                                    update_csv(path, up, a, 9)
                            
                        else:
                            return"Sorry, you didn't enter the information correctly!\nPlease try again later"
                    else:
                        return"Sorry, you didn't enter the information correctly!\nPlease try again later"

                elif num == 'Users':
                    num = input("Which one should be updated?\n1.First name\n2.Last name\n3.Gender\n4.Country\n5.City\n6.Address\n7.Age\n8.Landline numbe\n9.Mobile number\n10.Gmail\n11.User name\n12.Password\nWhich: ")
                    if num.isalnum() == True:
                        num = int(num)
                        if   num ==  1:
                            up = update_fname(first_name=input("What is your name?\n"))
                            if up != False:
                                path = "Normal_user.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 2) == True:
                                    a = search_value001(path, value, 2)
                                    a = a[0]
                                    update_csv(path, up, a, 2)

                        elif num ==  2:
                            up = update_lname(last_name=input("And your last name?\n"))
                            if up != False:
                                path = "Normal_user.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 3) == True:
                                    a = search_value001(path, value, 3)
                                    a = a[0]
                                    update_csv(path, up, a, 3)

                        elif num ==  3:
                            up = update_gender(gender=input("Your gender(please enter a number):\n1.Male\n2.Female\n3.Etc\n"))
                            if up != False:
                                path = "Normal_user.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 4) == True:
                                    a = search_value001(path, value, 4)
                                    a = a[0]
                                    update_csv(path, up, a, 4)

                        elif num ==  4:
                            up = update_contry(country=input("Country:\n"))
                            if up != False:
                                path = "Normal_user.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 5) == True:
                                    a = search_value001(path, value, 5)
                                    a = a[0]
                                    update_csv(path, up, a, 5)

                        elif num ==  5:
                            up = update_city(city=input("In which city do you live?\n"))
                            if up != False:
                                path = "Normal_user.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 6) == True:
                                    a = search_value001(path, value, 6)
                                    a = a[0]
                                    update_csv(path, up, a, 6)

                        elif num ==  6:
                            up = update_address(address=input("Please enter your address:\n"))
                            if up != False:
                                path = "Normal_user.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 7) == True:
                                    a = search_value001(path, value, 7)
                                    a = a[0]
                                    update_csv(path, up, a, 7)

                        elif num ==  7:
                            up = update_age(age=input("How old are you?\n"))
                            if up != False:
                                path = "Normal_user.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 8) == True:
                                    a = search_value001(path, value, 8)
                                    a = a[0]
                                    update_csv(path, up, a, 8)

                        elif num ==  8:
                            up = update_landline_number(landline_number=input("Landline number:\n"))
                            if up != False:
                                path = "Normal_user.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 9) == True:
                                    a = search_value001(path, value, 9)
                                    a = a[0]
                                    update_csv(path, up, a, 9)

                        elif num ==  9:
                            up = update_mobile_number(mobile_number=input("And mobile number:\n"))
                            if up != False:
                                path = "Normal_user.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 10) == True:
                                    a = search_value001(path, value, 10)
                                    a = a[0]
                                    update_csv(path, up, a, 10)

                        elif num == 10:
                            up = update_gmail(gmail=input("Please enter your gmail:\n"))
                            if up != False:
                                path = "Normal_user.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 11) == True:
                                    a = search_value001(path, value, 11)
                                    a = a[0]
                                    update_csv(path, up, a, 11)

                        elif num == 11:
                            up = update_username(8)
                            if up != False:
                                path = "Normal_user.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 14) == True:
                                    a = search_value001(path, value, 14)
                                    a = a[0]
                                    update_csv(path, up, a, 14)

                        elif num == 12:
                            up = update_password(8)
                            if up != False:
                                path = "Normal_user.csv"
                                value = input("Enter a Account number")
                                if search_value_managem(path, value, 15) == True:
                                    a = search_value001(path, value, 15)
                                    a = a[0]
                                    update_csv(path, up, a, 15)

                        else:
                            return"Sorry, you didn't enter the information correctly!\nPlease try again later"

                    else:
                        return"Sorry, you didn't enter the information correctly!\nPlease try again later"
                else:
                    return"Sorry, you didn't enter the information correctly!\nPlease try again later"
                

            else:
                return"Sorry, you didn't enter the information correctly!\nPlease try again later"
                    



        def show_file(self):
            file = input("1.Managers\n2.Normal users\nwhich file: ")
            if file.isalnum() == True:
                file = int(file)
                if file == 1:
                    type_value = input("1.Managem code\n2.First name\n3.Last name\n4.Gender\n5.City\n6.Address\n7.Mobile number\n8.Provinc\n9.Username\nwhich: ")
                    if type_value.isalnum() == True:
                        type_value = int(type_value)
                        path = "Managem.csv"
                        if type_value   == 1:
                            value = 'Managem code'
                            show(path, value)

                        elif type_value == 2:
                            value = 'First name'
                            show(path, value)

                        elif type_value == 3:
                            value = 'Last name'
                            show(path, value)

                        elif type_value == 4:
                            value = 'Gender'
                            show(path, value)

                        elif type_value == 5:
                            value = 'City'
                            show(path, value)

                        elif type_value == 6:
                            value = 'Address'
                            show(path, value)

                        elif type_value == 7:
                            value = 'Mobile number'
                            show(path, value)

                        elif type_value == 8:
                            value = 'Provinc'
                            show(path, value)

                        elif type_value == 9:
                            value = 'User name'
                            show(path, value)

                        else:
                            return"Sorry, you didn't enter the information correctly!\nPlease try again later"
                elif file == 2:
                    type_value = input("1.Number\n2.Account number\n3.First name\n4.Last name\n5.Gender\n6.Country\n7.City\n8.Address\n9.Age\n10.Landline number\n11.Mobile number\n12.Gmail\n13.Initial amount\n14.Amount\n15.Username\n16.Date of registration\nwhich: ")
                    if type_value.isalnum() == True:
                        type_value = int(type_value)
                        path = "Normal_user.csv"
                        if type_value   == 1:
                            value = 'Number'
                            show(path, value)

                        elif type_value   == 2:
                            value = 'Account number'
                            show(path, value)

                        elif type_value   == 3:
                            value = 'First name'
                            show(path, value)

                        elif type_value   == 4:
                            value = 'Last name'
                            show(path, value)
                        
                        elif type_value   == 5:
                            value = 'Gender'
                            show(path, value)

                        elif type_value   == 6:
                            value = 'Country'
                            show(path, value)

                        elif type_value   == 7:
                            value = 'City'
                            show(path, value)

                        elif type_value   == 8:
                            value = 'Address'
                            show(path, value)

                        elif type_value   == 9:
                            value = 'Age'
                            show(path, value)

                        elif type_value   == 10:
                            value = 'Landline number'
                            show(path, value)

                        elif type_value   == 11:
                            value = 'Mobile number'
                            show(path, value)

                        elif type_value   == 12:
                            value = 'Gmail'
                            show(path, value)

                        elif type_value   == 13:
                            value = 'Initial amount'
                            show(path, value)

                        elif type_value   == 14:
                            value = 'Amount'
                            show(path, value)

                        elif type_value   == 15:
                            value = 'User name'
                            show(path, value)

                        elif type_value   == 16:
                            value = 'Date of registration'
                            show(path, value)
                        else:
                            return"Sorry, you didn't enter the information correctly!\nPlease try again later"
                else:
                    return"Sorry, you didn't enter the information correctly!\nPlease try again later"
            else:
                return"Sorry, you didn't enter the information correctly!\nPlease try again later"
            


        def registration_of_a_number_of_users(self,path,new_path):
            self.path, self.new_path = path, new_path
            transfer_file_in_file(path, new_path)


    class Normal_user:
        def __init__(self):
            pass




        def new_normal_user(self):
            #Key to the correctness of user information
            key = False

            """To register the new manager:
                1.The first step is to get information from the user
                The first strage has two modes:1.question and answer 2.linear"""
            
            #Giving the user the right to choose
            item = input("How do you enter information?\n1.Question and answer\n2.Linear\n(please use 1 and 2):\n")
            if item.isalpha() == False:
                item = input("How do you enter information?\n1.Question and answer\n2.Linear\n(please use 1 and 2):\n")

                """If the user enters the number 1, he must enter the information linearly"""
            if item == '1':
                lst_new_normal_user = input("The information consists of:\n1.first name\n2.last name\n3.gender\n4.country\n5.city\n6.address\n7.age\n8.landline numbe\n9.mobile number\n10.gmail\n11.initial amount\nNOT:PLEASE WRITE IN ORDER\n")
                lnm = lst_new_normal_user.split()
                #If the number is correct, the information is saved and enters step 2(that is, check the information)
                if len(lnm) == 7:
                    first_name      = lnm[0]
                    last_name       = lnm[1]
                    gender          = lnm[2]
                    country         = lnm[3]
                    city            = lnm[4]
                    address         = lnm[5]
                    age             = lnm[6]
                    landline_number = lnm[7]
                    mobile_number   = lnm[8]
                    gmail           = lnm[9]
                    initial_amount  = lnm[10]
                    key             = True
                #If it was wrong, we will give the user a chance
                else:
                        print("Try again later")

                """If the user enters the number 2, he must enter the information in the form of a question"""
            elif item == '2':
                first_name      = input("What is your name?\n")
                last_name       = input("And your last name?\n")
                gender          = input("Your gender(please enter a number):\n1.Male\n2.Female\n3.Etc\n")
                country         = input("Country:\n")
                city            = input("In which city do you live?\n")
                address         = input("please enter your address:\n")
                age             = input("How old are you?\n")
                landline_number = input("Landline number:\n")
                mobile_number   = input("And mobile number:\n")
                gmail           = input("Please enter your gmail:\n")
                initial_amount  = input("The minimum amount to open an account is 200!, initial amount?\n")
                key             = True
            else:
                print("Please try again...")
            
            #If it was a key(key == True), filters information
            if key == True:
                #Data filtering
                user_type = 'Normal_user'
                filters(user_type, first_name, last_name, gender, city, address, mobile_number, country, age, landline_number, gmail, initial_amount)
            else:
                print("Please try again later")
        


        def info_normaluser(self):
            if login('8') == True:
                path = 'Normal_user'
                info = loc(path)
                print(info)



        def update(self):
            if login('8') == True:
                path = 'Normal_user'
                num = input("Which one do you want to update(please enter a number):\n1.Password\n2.Phone number\n3.Fixed number\n4.Address\n5.Email\n")
                if num.isalnum() == True:
                    num = int(num)
                    if num == 1:
                        up = update_password('8')
                        if up != False:
                            path = "Normal_user.csv"
                            value = input("Enter a Account number")
                            if search_value_managem(path, value, 1) == True:
                                a = search_value001(path, value, 8)
                                a = a[0]
                                update_csv(path, up, a, 14)

                    elif num == 2:
                        phone_number = input("Enter a new phone number:")
                        up = update_mobile_number(phone_number)
                        if up != False:
                            path = "Normal_user.csv"
                            value = input("Enter a Account number")
                            if search_value_managem(path, value, 1) == True:
                                a = search_value001(path, value, 8)
                                a = a[0]
                                update_csv(path, up, a, 14)
                    elif num == 3:
                        fixed_number = input("Enter a new landline number:")
                        up = update_landline_number(fixed_number)
                        if up != False:
                            path = "Normal_user.csv"
                            value = input("Enter a Account number")
                            if search_value_managem(path, value, 1) == True:
                                a = search_value001(path, value, 8)
                                a = a[0]
                                update_csv(path, up, a, 14)
                    elif num == 4:
                        address = input("Enter a new address:")
                        up = update_address(address)
                        if up != False:
                            path = "Normal_user.csv"
                            value = input("Enter a Account number")
                            if search_value_managem(path, value, 1) == True:
                                a = search_value001(path, value, 8)
                                a = a[0]
                                update_csv(path, up, a, 14)
                    elif num == 5:
                        email = input("Enter a new email:")
                        up = update_gmail(email)
                        if up != False:
                            path = "Normal_user.csv"
                            value = input("Enter a Account number")
                            if search_value_managem(path, value, 1) == True:
                                a = search_value001(path, value, 8)
                                a = a[0]
                                update_csv(path, up, a, 14)
                    else:
                        return"Sorry, you didn't enter the information correctly!\nPlease try again later"
                    


        def money_transfer(self):     
            if login('8') == True:
                path = 'Normal_user'
                info_1 = loc(path)
                destination_card = input("Destination card:")
                if search_value_managem(path, destination_card, 1) == True:
                    money_transfer = input("Deposit amount?")
                    if money_transfer.isalnum() == True:
                        user_amount = int(info_1[13])
                        money_transfer = int(money_transfer)
                        if user_amount >= money_transfer:
                            user_amount -= money_transfer
                            user_card = info_1[1]
                            a = search_value001(path, user_card, 1)
                            indexa = a[0]
                            b = search_value001(path, destination_card, 1)
                            indexb = b[0]
                            info_2 = loc(path, indexb)
                            money_transfer0 = info_2[13] + money_transfer
                            update_csv(path, user_amount, indexa , 13)
                            update_csv(path, money_transfer0, indexb, 13)
                            lst = []
                            lst = lst.append(user_card)
                            lst = lst.append(destination_card)
                            lst = lst.append(money_transfer)
                            lst = lst.append(time())
                            path0 = "Transaction.csv"
                            appending_file(path0, lst)
                            print(f"The transfer was successful\nSource account number:{user_card}\nDestination account number:{destination_card}\nThe name of the destination account holder:{info_2[2]}\nAmount transferred{money_transfer}")
                        else:
                            return"Insufficient inventory"
